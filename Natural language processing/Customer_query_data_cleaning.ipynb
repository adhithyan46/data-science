# %%
import pandas as pd

# %%
df = pd.read_csv("customer_queries_dataset.csv")
df.head()
# Out:
#                                 query            label
# 0   Can you update me on my delivery?     Order Status
# 1        How long does delivery take?    Shipping Info
# 2               I forgot my password.    Account Issue
# 3  What are the specs of this laptop?  Product Inquiry
# 4           I want to return my item.          Returns

# %%
df.shape
# Out:
# (210, 2)

# %%
df['label'].value_counts()
# Out:
# label
# Order Status       35
# Shipping Info      35
# Account Issue      35
# Product Inquiry    35
# Returns            35
# Technical Issue    35
# Name: count, dtype: int64

# %%
df['cleaned_query'] = df['query'].str.lower()
df['cleaned_query'] = df['cleaned_query'].str.replace(r'[^A-Za-z0-9 ]+', '',regex=True)
df['cleaned_label'] = df['label'].str.lower()
df
# Out:
#                                   query            label  \
# 0     Can you update me on my delivery?     Order Status
# 1          How long does delivery take?    Shipping Info
# 2                 I forgot my password.    Account Issue
# 3    What are the specs of this laptop?  Product Inquiry
# 4             I want to return my item.          Returns
# ..                                  ...              ...
# 205         Why is the website so slow?  Technical Issue
# 206  What is the status of my shipment?     Order Status
# 207           Why is my account locked?    Account Issue
# 208        Is this item still in stock?  Product Inquiry
# 209    How do I reset my login details?    Account Issue
#
#                          cleaned_query    cleaned_label
# 0     can you update me on my delivery     order status
# 1          how long does delivery take    shipping info
# 2                 i forgot my password    account issue
# ...

# %%
# Out:
#                                   query            label  \
# 0     Can you update me on my delivery?     Order Status
# 1          How long does delivery take?    Shipping Info
# 2                 I forgot my password.    Account Issue
# 3    What are the specs of this laptop?  Product Inquiry
# 4             I want to return my item.          Returns
# ..                                  ...              ...
# 205         Why is the website so slow?  Technical Issue
# 206  What is the status of my shipment?     Order Status
# 207           Why is my account locked?    Account Issue
# 208        Is this item still in stock?  Product Inquiry
# 209    How do I reset my login details?    Account Issue
#
#                          cleaned_query    cleaned_label
# 0     can you update me on my delivery     order status
# 1          how long does delivery take    shipping info
# 2                 i forgot my password    account issue
# ...

# %%
df.to_csv("Customer_query_classificatio.csv",index= False)
