# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
import PyPDF2
from pprint import pprint

# %%
nltk.download("punkt_tab")
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
phrase = []
with open("Types_of_Bikes_Document.pdf","rb") as file:
  reader = PyPDF2.PdfReader(file)
  for page in reader.pages:
    text = page.extract_text()
    print(text)
# Out:
# Types of Bikes
# Road Bike
# Road bikes are lightweight bicycles designed for speed on paved roads. They have narrow tires,
# drop handlebars, and multiple gears for riding on flat and hilly terrain.
# Mountain Bike
# Mountain bikes are built for off-road trails and rough terrains. They come with wide, knobby tires,
# strong frames, and suspension systems to absorb shock.
# Hybrid Bike
# A hybrid bike combines features of both road and mountain bikes. It's suitable for commuting,
# fitness, and light off-road use, offering a comfortable upright position.
# Touring Bike
# Touring bikes are designed for long-distance travel. They have sturdy frames, racks for carrying
# luggage, and comfortable geometry for extended rides.
# BMX Bike
# BMX bikes are small, durable bikes designed for tricks, racing, and stunts. They have a single gear
# and strong frames for performing jumps and tricks.
# Electric Bike (E-Bike)
# Electric bikes include a motor that assists with pedaling. They are popular for commuting and
# reducing physical strain on long rides.
# Folding Bike
# Folding bikes are compact bicycles that can be folded for easy storage and transport. They are ideal
# for urban commuting and public transport.
# Cruiser Bike
# Cruiser bikes feature wide tires, upright handlebars, and comfortable saddles. They're best for
# casual riding along flat paths and beaches.
# Track Bike (Fixie)
# Track bikes are fixed-gear bicycles often used on velodromes. They have no brakes and are
# designed for racing on smooth tracks.
# Recumbent Bike
# Recumbent bikes allow the rider to recline in a laid-back position. They provide ergonomic support
# and are often used for long-distance cycling.
# Gravel Bike
# Gravel bikes are versatile bikes that perform well on both paved and unpaved roads. They have
# drop bars like road bikes but wider tires for off-road stability.
# Fat Bike
# Fat bikes have oversized tires designed for snow, sand, and other soft terrains. They offer stability
# and grip where traditional bikes struggle.
# Cyclocross Bike
# Cyclocross bikes are lightweight and built for racing on mixed terrain, including grass, mud, and
# gravel. They are similar to road bikes but more rugged.

# %%
words = word_tokenize(text)
words
# Out:
# ['casual',
#  'riding',
#  'along',
#  'flat',
#  'paths',
#  'and',
#  'beaches',
#  '.',
#  'Track',
#  'Bike',
#  '(',
#  'Fixie',
#  ')',
#  'Track',
#  'bikes',
#  'are',
#  'fixed-gear',
#  'bicycles',
#  'often',
#  'used',
#  'on',
#  'velodromes',
#  '.',
#  'They',
#  'have',
#  'no',
#  'brakes',
#  'and',
#  'are',
#  'designed',
#  'for',
#  'racing',
#  'on',
#  'smooth',
#  'tracks',
#  '.',
#  'Recumbent',
#  'Bike',
#  'Recumbent',
#  'bikes',
#  'allow',
#  'the',
#  'rider',
#  'to',
#  'recline',
#  'in',
#  'a',
#  'laid-back',
#  'position',
#  '.',
#  'They',
#  'provide',
#  'ergonomic',
#  'support',
#  'and',
#  'are',
#  'often',
#  'used',
#  'for',
#  'long-distance',
#  'cycling',
#  '.',
#  'Gravel',
#  'Bike',
#  'Gravel',
#  'bikes',
#  'are',
#  'versatile',
#  'bikes',
#  'that',
#  'perform',
#  'well',
#  'on',
#  'both',
#  'paved',
#  'and',
#  'unpaved',
#  'roads',
#  '.',
#  'They',
#  'have',
#  'drop',
#  'bars',
#  'like',
#  'road',
#  'bikes',
#  'but',
#  'wider',
#  'tires',
#  'for',
#  'off-road',
#  'stability',
#  '.',
#  'Fat',
#  'Bike',
#  'Fat',
#  'bikes',
#  'have',
#  'oversized',
#  'tires',
#  'designed',
#  'for',
#  'snow',
#  ',',
#  'sand',
#  ',',
#  'and',
#  'other',
#  'soft',
#  'terrains',
#  '.',
#  'They',
#  'offer',
#  'stability',
#  'and',
#  'grip',
#  'where',
#  'traditional',
#  'bikes',
#  'struggle',
#  '.',
#  'Cyclocross',
#  'Bike',
#  'Cyclocross',
#  'bikes',
#  'are',
#  'lightweight',
#  'and',
#  'built',
#  'for',
#  'racing',
#  'on',
#  'mixed',
#  'terrain',
#  ',',
#  'including',
#  'grass',
#  ',',
#  'mud',
#  ',',
#  'and',
#  'gravel',
#  '.',
#  'They',
#  'are',
#  'similar',
#  'to',
#  'road',
#  'bikes',
#  'but',
#  'more',
#  'rugged',
#  '.']
