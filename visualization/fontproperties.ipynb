# %%
import pandas as pd
import numpy as np
df=pd.read_csv('TV_show_data.csv')
df
# Out:
#                             Name  \
# 0                   Breaking Bad
# 1                        Firefly
# 2     Avatar: The Last Airbender
# 3                       Sherlock
# 4                Attack on Titan
# ...                          ...
# 1528            All-Star Academy
# 1529     Neighbors with Benefits
# 1530                 Funny Girls
# 1531      Cedric's Barber Battle
# 1532              The Ambassador
#
#                                                 Summary  Average Runtime  \
# 0     Breaking Bad follows protagonist Walter White,...             60.0
# 1     Five hundred years in the future, a renegade c...             64.0
# 2     Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3     Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4     Known in Japan as Shingeki no Kyojin, many yea...             26.0
# ...                                                 ...              ...
# ...

# %%
import matplotlib.pyplot as plt
x=df['Rating']
y=df['Type']
z=df['Language']
plt.ylabel('type')
plt.xlabel('rating')
plt.title('tv show rating',loc='left')

# plt.plot(y)
plt.plot(x,y,c='y',linewidth='2.0')
plt.legend(['rating','type'])

plt.show()

# %%
x=df['Rating']
y=df['Type']
font1={'family':'arial','color':'g','size':'20'}
font2={'family':'arial','color':'r','size':'15'}
plt.title("Tv show rating",fontdict=font1,loc='left')
plt.xlabel('Rating',fontdict=font2)
plt.ylabel('Type',fontdict=font2)
plt.plot(x,y,c='r')
plt.grid(c='g',linestyle='--')
plt.legend(['rating'  ])
# plt.grid(axis='x')
# plt.grid(axis='y')
plt.show()
