# %%
import pandas as pd
# import numpy as np
df=pd.read_csv('cardata.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df['Selling_Price'].max()
# Out:
# 35.0

# %%
from sklearn.preprocessing import Normalizer
scaler=Normalizer()
numeric_cols=['Year','Selling_Price','Present_Price','Kms_Driven','Owner']
df[numeric_cols]=scaler.fit_transform(df[numeric_cols])
df.head()
# Out:
#   Car_Name      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  0.074386       0.000124       0.000206    0.997229    Petrol
# 1      sx4  0.046763       0.000110       0.000222    0.998906    Diesel
# 2     ciaz  0.280576       0.001009       0.001370    0.959830    Petrol
# 3  wagon r  0.360697       0.000511       0.000744    0.932683    Petrol
# 4    swift  0.047391       0.000108       0.000162    0.998876    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual    0.0
# 1      Dealer       Manual    0.0
# 2      Dealer       Manual    0.0
# 3      Dealer       Manual    0.0
# 4      Dealer       Manual    0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x=df['Fuel_Type']
y=df['Kms_Driven']
plt.xlabel('fuel')
plt.ylabel('Driven')
plt.plot(x,c='orange')
plt.plot(y,c='r')
plt.legend(['fuel','Driven'])
plt.grid(ls='--')
plt.show()

# %%
plt.hist(x,color='green')
# Out:
# (array([239.,   0.,   0.,   0.,   0.,  60.,   0.,   0.,   0.,   2.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
fuel_count=df['Fuel_Type'].value_counts()
fuel_count
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
x=[239,60,2]
fuels=['Petrol','Diesel','CNG']
colors=['orange','powderblue','green']
explode=[0.2,0.0,0.0]
plt.pie(x,labels=fuels,colors=colors,autopct='%1.1f%%',explode=explode,shadow=True)
plt.show()

# %%
import numpy as np
x=df['Selling_Price']
y=df['Present_Price']
colors=np.random.rand(301)
plt.scatter(x,y,c=colors,cmap='viridis')
plt.show()

# %%
plt.bar(x,y)
        
plt.show()

# %%
x=df['Selling_Price']
y=df['Present_Price']
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('price',loc='left')
plt.figure(figsize=(10,6))
x=df['Fuel_Type']
y=df['Transmission']
plt.subplot(1,2,2)
plt.plot(x,y,c='r')
plt.title('fuel',loc='left')
plt.show()
