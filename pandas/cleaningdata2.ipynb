# %%
import pandas as pd
df=pd.read_csv('TV_show_data.csv')
df
# Out:
#                             Name  \
# 0                   Breaking Bad
# 1                        Firefly
# 2     Avatar: The Last Airbender
# 3                       Sherlock
# 4                Attack on Titan
# ...                          ...
# 1528            All-Star Academy
# 1529     Neighbors with Benefits
# 1530                 Funny Girls
# 1531      Cedric's Barber Battle
# 1532              The Ambassador
#
#                                                 Summary  Average Runtime  \
# 0     Breaking Bad follows protagonist Walter White,...             60.0
# 1     Five hundred years in the future, a renegade c...             64.0
# 2     Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3     Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4     Known in Japan as Shingeki no Kyojin, many yea...             26.0
# ...                                                 ...              ...
# ...

# %%
df.head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                              Summary  Average Runtime  \
# 0  Breaking Bad follows protagonist Walter White,...             60.0
# 1  Five hundred years in the future, a renegade c...             64.0
# 2  Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3  Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4  Known in Japan as Shingeki no Kyojin, many yea...             26.0
#
#      End Date Premiere Date                                       Genres  \
# 0  2008-01-20    2019-10-11               ['Drama', 'Crime', 'Thriller']
# 1  2002-09-20    2002-12-20    ['Drama', 'Adventure', 'Science-Fiction']
# 2  2005-02-21    2008-07-19           ['Action', 'Adventure', 'Fantasy']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1533 entries, 0 to 1532
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1533 non-null   object
#  1   Summary          1533 non-null   object
#  2   Average Runtime  1532 non-null   float64
#  3   End Date         1532 non-null   object
#  4   Premiere Date    1377 non-null   object
#  5   Genres           1533 non-null   object
#  6   Type             1533 non-null   object
#  7   Language         1533 non-null   object
#  8   Network          1464 non-null   object
#  9   Rating           1255 non-null   float64
#  10  Schedule (days)  1533 non-null   object
#  11  Schedule (time)  1366 non-null   object
#  12  Total Seasons    1533 non-null   int64
#  13  Total Episodes   1533 non-null   int64
#  14  Character Names  1376 non-null   object
#  15  Person Names     1376 non-null   object
# ...

# %%
#selecting columns
df['Name'].head()
# Out:
# 0                  Breaking Bad
# 1                       Firefly
# 2    Avatar: The Last Airbender
# 3                      Sherlock
# 4               Attack on Titan
# Name: Name, dtype: object

# %%
df.Name.head()
# Out:
# 0                  Breaking Bad
# 1                       Firefly
# 2    Avatar: The Last Airbender
# 3                      Sherlock
# 4               Attack on Titan
# Name: Name, dtype: object

# %%
#seleting multiple columns
df_1=df[['Name','Average Runtime']]
df_1
# Out:
#                             Name  Average Runtime
# 0                   Breaking Bad             60.0
# 1                        Firefly             64.0
# 2     Avatar: The Last Airbender             30.0
# 3                       Sherlock             90.0
# 4                Attack on Titan             26.0
# ...                          ...              ...
# 1528            All-Star Academy             60.0
# 1529     Neighbors with Benefits             60.0
# 1530                 Funny Girls             60.0
# 1531      Cedric's Barber Battle             30.0
# 1532              The Ambassador             50.0
#
# [1533 rows x 2 columns]

# %%
cols=['Name','Average Runtime']
df_1=df[cols]
df_1.head()
# Out:
#                          Name  Average Runtime
# 0                Breaking Bad             60.0
# 1                     Firefly             64.0
# 2  Avatar: The Last Airbender             30.0
# 3                    Sherlock             90.0
# 4             Attack on Titan             26.0

# %%
#selecting with dtype
df[['Name',"Average Runtime"]].get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5452\3096007037.py in ?()
#       1 #selecting with dtype
# ----> 2 df[['Name',"Average Runtime"]].get_dtype_counts()
#
# E:\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
df.select_dtype(include=['float']).head()

# %%
#filter
df.filter(like="Date").head()
# Out:
#      End Date Premiere Date
# 0  2008-01-20    2019-10-11
# 1  2002-09-20    2002-12-20
# 2  2005-02-21    2008-07-19
# 3  2010-07-25    2017-01-15
# 4  2013-04-07    2023-11-04

# %%
df.filter(like='Name').head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                      Character Names  \
# 0  0-Walter White, 1-Jesse Pinkman, 2-Skyler Whit...
# 1  0-Captain Malcolm "Mal" Reynolds, 1-Zoe Alleyn...
# 2  0-Aang, 1-Katara, 2-Sokka, 3-Zuko, 4-Appa, 5-M...
# 3               0-Sherlock Holmes, 1-Dr. John Watson
# 4   0-Mikasa Ackerman, 1-Armin Arlert, 2-Eren Jaeger
#
#                                         Person Names
# 0  0-Bryan Cranston, 1-Aaron Paul, 2-Anna Gunn, 3...
# 1  0-Nathan Fillion, 1-Gina Torres, 2-Alan Tudyk,...
# 2  0-Zach Tyler, 1-Mae Whitman, 2-Jack De Sena, 3...
# 3           0-Benedict Cumberbatch, 1-Martin Freeman
# 4        0-Yui Ishikawa, 1-Marina Inoue, 2-Yûki Kaji

# %%
#selecting all columns
df.columns

# %%
group_1=['Name', 'Summary','Genres', 'Type','Schedule (time)', 'Total Seasons']
group_2=[ 'Average Runtime', 'End Date', 'Language', 'Network','Total Episodes', 'Character Names']
group_3=['Premiere Date','Rating', 'Schedule (days)','Person Names', 'Official Site']

# %%
#concatinating all groups to new_cols
new_cols=group_1+group_2+group_3

# %%
#checking both are same
set(df.columns)==set(new_cols)
# Out:
# True

# %%
df_1=df[new_cols]
df_1.head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                              Summary  \
# 0  Breaking Bad follows protagonist Walter White,...
# 1  Five hundred years in the future, a renegade c...
# 2  Water. Earth. Fire. Air. Only the Avatar was t...
# 3  Sherlock Holmes and Dr. John Watson's adventur...
# 4  Known in Japan as Shingeki no Kyojin, many yea...
#
#                                         Genres       Type Schedule (time)  \
# 0               ['Drama', 'Crime', 'Thriller']   Scripted           22:00
# 1    ['Drama', 'Adventure', 'Science-Fiction']   Scripted           20:00
# 2           ['Action', 'Adventure', 'Fantasy']  Animation           11:00
# 3                ['Drama', 'Crime', 'Mystery']   Scripted           21:00
# 4  ['Action', 'Adventure', 'Anime', 'Fantasy']  Animation           00:10
#
# ...

# %%
#changing index
# df_name=df.drop_duplicates(subset='Name')
# df_name.shape

# %%
#setting index
df.set_index('Name',inplace=True)
df.head()
# Out:
#                                                                       Summary  \
# Name
# Breaking Bad                Breaking Bad follows protagonist Walter White,...
# Firefly                     Five hundred years in the future, a renegade c...
# Avatar: The Last Airbender  Water. Earth. Fire. Air. Only the Avatar was t...
# Sherlock                    Sherlock Holmes and Dr. John Watson's adventur...
# Attack on Titan             Known in Japan as Shingeki no Kyojin, many yea...
#
#                             Average Runtime    End Date Premiere Date  \
# Name
# Breaking Bad                           60.0  2008-01-20    2019-10-11
# Firefly                                64.0  2002-09-20    2002-12-20
# Avatar: The Last Airbender             30.0  2005-02-21    2008-07-19
# Sherlock                               90.0  2010-07-25    2017-01-15
# Attack on Titan                        26.0  2013-04-07    2023-11-04
#
# ...

# %%
#selecting rows using iloc
df.iloc[2]
# Out:
# Summary            Water. Earth. Fire. Air. Only the Avatar was t...
# Average Runtime                                                 30.0
# End Date                                                  2005-02-21
# Premiere Date                                             2008-07-19
# Genres                            ['Action', 'Adventure', 'Fantasy']
# Type                                                       Animation
# Language                                                     English
# Network                                                  Nickelodeon
# Rating                                                           8.9
# Schedule (days)                                         ['Saturday']
# Schedule (time)                                                11:00
# Total Seasons                                                      3
# Total Episodes                                                    61
# Character Names    0-Aang, 1-Katara, 2-Sokka, 3-Zuko, 4-Appa, 5-M...
# ...

# %%
df.loc[['Attack on Titan']]
# Out:
#                                                            Summary  \
# Name
# Attack on Titan  Known in Japan as Shingeki no Kyojin, many yea...
#
#                  Average Runtime    End Date Premiere Date  \
# Name
# Attack on Titan             26.0  2013-04-07    2023-11-04
#
#                                                       Genres       Type  \
# Name
# Attack on Titan  ['Action', 'Adventure', 'Anime', 'Fantasy']  Animation
#
#                  Language Network  Rating Schedule (days) Schedule (time)  \
# Name
# Attack on Titan  Japanese     NHK     8.9    ['Saturday']           00:10
#
#                  Total Seasons  Total Episodes  \
# Name
# Attack on Titan              4              89
#
#                                                   Character Names  \
# Name
# Attack on Titan  0-Mikasa Ackerman, 1-Armin Arlert, 2-Eren Jaeger
#
#                                                 Person Names  \
# Name
# ...

# %%
df.iloc[[2,4,6]]
# Out:
#                                                                       Summary  \
# Name
# Avatar: The Last Airbender  Water. Earth. Fire. Air. Only the Avatar was t...
# Attack on Titan             Known in Japan as Shingeki no Kyojin, many yea...
# One Piece                   One Piece animation is based on the successful...
#
#                             Average Runtime    End Date Premiere Date  \
# Name
# Avatar: The Last Airbender             30.0  2005-02-21    2008-07-19
# Attack on Titan                        26.0  2013-04-07    2023-11-04
# One Piece                              26.0  1999-10-20           NaN
#
#                                                                  Genres  \
# Name
# Avatar: The Last Airbender           ['Action', 'Adventure', 'Fantasy']
# Attack on Titan             ['Action', 'Adventure', 'Anime', 'Fantasy']
# One Piece                   ['Action', 'Adventure', 'Anime', 'Fantasy']
#
# ...

# %%
#silicing
df.iloc[1:7]
# Out:
#                                                                       Summary  \
# Name
# Firefly                     Five hundred years in the future, a renegade c...
# Avatar: The Last Airbender  Water. Earth. Fire. Air. Only the Avatar was t...
# Sherlock                    Sherlock Holmes and Dr. John Watson's adventur...
# Attack on Titan             Known in Japan as Shingeki no Kyojin, many yea...
# The Wire                    The first season of The Wire (2002) concentrat...
# One Piece                   One Piece animation is based on the successful...
#
#                             Average Runtime    End Date Premiere Date  \
# Name
# Firefly                                64.0  2002-09-20    2002-12-20
# Avatar: The Last Airbender             30.0  2005-02-21    2008-07-19
# Sherlock                               90.0  2010-07-25    2017-01-15
# Attack on Titan                        26.0  2013-04-07    2023-11-04
# ...

# %%
first='Attack on Titan'
last='One Piece'
df.loc[first:last]
# Out:
#                                                            Summary  \
# Name
# Attack on Titan  Known in Japan as Shingeki no Kyojin, many yea...
# The Wire         The first season of The Wire (2002) concentrat...
# One Piece        One Piece animation is based on the successful...
#
#                  Average Runtime    End Date Premiere Date  \
# Name
# Attack on Titan             26.0  2013-04-07    2023-11-04
# The Wire                    60.0  2002-06-02    2008-03-09
# One Piece                   26.0  1999-10-20           NaN
#
#                                                       Genres       Type  \
# Name
# Attack on Titan  ['Action', 'Adventure', 'Anime', 'Fantasy']  Animation
# The Wire                                  ['Drama', 'Crime']   Scripted
# One Piece        ['Action', 'Adventure', 'Anime', 'Fantasy']  Animation
#
#                  Language  Network  Rating Schedule (days) Schedule (time)  \
# Name
# ...

# %%
#selecting rows and columns
df.iloc[:,[3,4,7]].head()#selecting all rows and 3,4,7 columns
# Out:
#                            Premiere Date  \
# Name
# Breaking Bad                  2019-10-11
# Firefly                       2002-12-20
# Avatar: The Last Airbender    2008-07-19
# Sherlock                      2017-01-15
# Attack on Titan               2023-11-04
#
#                                                                  Genres  \
# Name
# Breaking Bad                             ['Drama', 'Crime', 'Thriller']
# Firefly                       ['Drama', 'Adventure', 'Science-Fiction']
# Avatar: The Last Airbender           ['Action', 'Adventure', 'Fantasy']
# Sherlock                                  ['Drama', 'Crime', 'Mystery']
# Attack on Titan             ['Action', 'Adventure', 'Anime', 'Fantasy']
#
#                                 Network
# Name
# Breaking Bad                        AMC
# Firefly                             FOX
# Avatar: The Last Airbender  Nickelodeon
# Sherlock                        BBC One
# Attack on Titan                     NHK
