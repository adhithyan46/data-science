# %%
import pandas as pd
df=pd.read_csv('Symptom-severity.csv')
df.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Symptom']=le.fit_transform(df['Symptom'])
df
# Out:
#      Symptom  weight
# 0         55       1
# 1        101       3
# 2         73       4
# 3         25       4
# 4         97       5
# ..       ...     ...
# 128       50       2
# 129       10       4
# 130       90       2
# 131      128       3
# 132       84       5
#
# [133 rows x 2 columns]

# %%
x=df[['Symptom']]
y=df['weight']
x
# Out:
#      Symptom
# 0         55
# 1        101
# 2         73
# 3         25
# 4         97
# ..       ...
# 128       50
# 129       10
# 130       90
# 131      128
# 132       84
#
# [133 rows x 1 columns]

# %%
y
# Out:
# 0      1
# 1      3
# 2      4
# 3      4
# 4      5
#       ..
# 128    2
# 129    4
# 130    2
# 131    3
# 132    5
# Name: weight, Length: 133, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
X_train
# Out:
#      Symptom
# 5         19
# 36        75
# 41        64
# 77       102
# 23        52
# ..       ...
# 87       125
# 103      123
# 67        74
# 24        26
# 8          2
#
# [93 rows x 1 columns]

# %%
X_test
# Out:
#      Symptom
# 28       110
# 132       84
# 46       113
# 75        38
# 33        28
# 70        86
# 35        60
# 114      107
# 25        45
# 11       122
# 128       50
# 32       131
# 29        29
# 105       83
# 110      121
# 51       117
# 108       95
# 111       88
# 43       130
# 109       58
# 72        15
# 62        54
# 21        59
# 57       124
# 84       104
# 73       115
# 54        94
# 37         6
# 45        42
# 92        80
# 26       109
# 115       33
# 123        8
# 101        1
# 76        35
# 69       114
# 90        43
# 22        81
# 74        37
# 106       39

# %%
y_train
# Out:
# 5      3
# 36     4
# 41     5
# 77     4
# 23     5
#       ..
# 87     4
# 103    4
# 67     4
# 24     4
# 8      3
# Name: weight, Length: 93, dtype: int64

# %%
y_test
# Out:
# 28     3
# 132    5
# 46     7
# 75     5
# 33     4
# 70     5
# 35     4
# 114    6
# 25     7
# 11     5
# 128    2
# 32     3
# 29     4
# 105    4
# 110    3
# 51     4
# 108    4
# 111    5
# 43     4
# 109    3
# 72     5
# 62     6
# 21     2
# 57     7
# 84     6
# 73     5
# 54     5
# 37     3
# 45     6
# 92     5
# 26     3
# 115    4
# 123    2
# 101    6
# 76     4
# 69     5
# 90     5
# 22     6
# 74     4
# 106    5
# Name: weight, dtype: int64

# %%
X_train.shape
# Out:
# (93, 1)

# %%
X_test.shape
# Out:
# (40, 1)

# %%
y_train.shape
# Out:
# (93,)

# %%
y_test.shape
# Out:
# (40,)

# %%
from sklearn.preprocessing import StandardScaler
cols=['Symptom']
sl=StandardScaler()
df[cols]=sl.fit_transform(df[cols])
df
# Out:
#       Symptom  weight
# 0   -0.271561       1
# 1    0.938496       3
# 2    0.201940       4
# 3   -1.060728       4
# 4    0.833274       5
# ..        ...     ...
# 128 -0.403089       2
# 129 -1.455312       4
# 130  0.649135       2
# 131  1.648747       3
# 132  0.491301       5
#
# [133 rows x 2 columns]

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([6, 6, 5, 6, 4, 6, 4, 4, 3, 4, 5, 4, 3, 5, 4, 5, 2, 2, 4, 3, 4, 2,
#        3, 4, 2, 5, 5, 4, 4, 4, 5, 6, 4, 4, 4, 5, 4, 5, 6, 5], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[0, 1, 1, 1, 0, 0],
#        [0, 1, 3, 1, 1, 0],
#        [1, 1, 4, 2, 2, 0],
#        [1, 0, 4, 4, 3, 0],
#        [2, 0, 3, 1, 0, 0],
#        [0, 1, 1, 1, 0, 0]], dtype=int64)
